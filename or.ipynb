# %% [markdown]
# <a href="https://colab.research.google.com/github/shorkelleyss-dot/Musiccomputing2026/blob/main/or.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def functionWithOptions(text):
    if text == "hi" or text == "hello":
        print("Greetings")
    elif text == "bye" or text == "goodbye":
        print("See you later")
    else:
        print(text)

# %%
functionWithOptions('hi')
# Out:
# Greetings

# %%
# note that it is case sensitive
functionWithOptions('Hi')
# Out:
# Hi

# %%
functionWithOptions('hello')
# Out:
# Greetings

# %%
functionWithOptions('bye')
# Out:
# See you later

# %%
functionWithOptions('goodbye')
# Out:
# See you later

# %%
functionWithOptions('Something else')
# Out:
# Something else
