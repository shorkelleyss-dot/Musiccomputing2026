# %% [markdown]
# <a href="https://colab.research.google.com/github/shorkelleyss-dot/Musiccomputing2026/blob/main/labassignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display
import IPython.display

# %%
def plotAudio2(sig,sampleRate,title):


   # this version expects the audio file to have already been opened by librosa


   # Adjust the x-axis to represent time


   time=np.arange(0,sig.shape[0])/sampleRate


   # Scale the y-axis to represent amplitude from -1 to 1
   excursion=max(abs(sig))
   sigNew = sig / excursion


   # Label the x and y axes with variables
   xlabel = 'Time (seconds)'
   ylabel = 'Amplitude'


   #plot the signal using the x and y axis variables
   plt.plot(time,sigNew)
   plt.xlabel(xlabel)
   plt.ylabel(ylabel)
   plt.title(title)
   plt.show()

# %%
def plotAudioFreqDomain(sig,sr,title,winSize,specType):

   # from Assignment 3
   # create a normalized spectrogram
   # this includes several function calls
   # first create a basic specgrogram with librosa.stft() with the default window size (2048)
   # then make all of values in the spectrogram positive with np.abs()
   # then scale the spectogram to be in decibels, so it better reflects how we hear librosa.amplitude_to_db()
   spec = librosa.amplitude_to_db(np.abs(librosa.stft(sig)), ref=np.max)

   # display the normalized spectrogram with a linear frequency scale
   librosa.display.specshow(spec, y_axis=specType)
   plt.colorbar(format='%+2.0f dB')
   plt.title('Linear-frequency power spectrogram')
   plt.show()

# %%
def additiveSynthesis(samplingRate,frequency,numHarmonics,seqHarm,ampExponent):

    # from additiveSynthesis.ipynb
    # generate list of harmonics
    harmonics = np.arange(1,numHarmonics+1,seqHarm)
    harmonics = harmonics[1:-1]
    print(harmonics)

    # create a time series from 0 to 1 the inputted length
    timeSeries = np.linspace(0, 1, samplingRate)
    print(timeSeries)

    # create a cosine wave for the fundamental
    signal = np.cos(2.0 * np.pi * frequency * timeSeries)

    # add harmonics based on the those specified in the variable 'harmonics'
    for harm in harmonics:
        signal = signal + np.cos(2.0 * np.pi * frequency * harm * timeSeries)/harm**ampExponent

    # scale the signal to between -1 and 1
    excursion=max(abs(signal))
    signal = signal / excursion

    # plot signal
    plt.plot(timeSeries,signal)
    plt.xlabel('Time (Sec)')
    plt.ylabel('Amplitude')
    plt.title('Additive Synthesis')
    plt.plot

    return signal

# %%
def makeWaveforms(frequency,samplingRate,numHarmonics,waveType):
    # use an if/elif/else statement to set up the parameters for
    # the different type of waveforms based on the code in
    # additiveSynthesis.ipynb
    # if, elif (else if) and else can be used to evaluate the contents of a variable

    if  waveType == 'sawtooth':
       seqHarm = 1
       ampExponent = 1
    elif waveType == 'square':
       seqHarm = 2
       ampExponent = 1
    elif waveType == 'triangle':
       seqHarm = 2
       ampExponent = 2
    else:
       numHarmonics = 1
       seqHarm = 1
       ampExponent = 1

    print(seqHarm)
    print(ampExponent)

    signal = additiveSynthesis(samplingRate,frequency,numHarmonics,seqHarm,ampExponent)
    IPython.display.Audio(data=signal, rate=samplingRate)

    samplingRate = 44100
    frequency = 100
    numHarmonics = 20
    waveType = 'sine'


    # call additiveSynthesis() to generate a waveform
    additiveSynthesis(samplingRate,frequency,numHarmonics,seqHarm,ampExponent)

    # return the generated waveform (signal)
    return signal

# %%
def visualizeWaveforms(frequency, samplingRate, numHarmonics, waveType):

  samplingRate = 44100
  frequency = 100
  numHarmonics = 20
  waveType = 'sine'

  # if, elif (else if) and else can be used to evaluate the contents of a variable
  if waveType == 'sawtooth':
    seqHarm = 1
    ampExponent = 1
  elif waveType == 'square':
    seqHarm = 2
    ampExponent = 1
  elif waveType == 'triangle':
    seqHarm = 2
    ampExponent = 2
  else:
    numHarmonics = 1
    seqHarm = 1
    ampExponent = 1

  signal = additiveSynthesis(samplingRate,frequency,numHarmonics,seqHarm,ampExponent)
  IPython.display.Audio(data=signal, rate=samplingRate)

  # call plotAudio2()
  plotAudio2(sig,sampleRate,title)

  # call plotAudioFreqDomain()
  plotAudioFreqDomain(sig,sr,title,winSize,specType)

  # return the output of makeWaveform()
  return signal

# %%
frequency = 100
samplingRate = 44100
numHarmonics = 100
waveType = 'sine'
winSize = 1024
specType = 'log'

#visualizeWaveforms()
visualizeWaveforms(frequency, samplingRate, numHarmonics, waveType)

#IPython.display.Audio()
# Out:
# []
# [0.00000000e+00 2.26762512e-05 4.53525023e-05 ... 9.99954647e-01
#  9.99977324e-01 1.00000000e+00]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_15802/358467116.py in <cell line: 0>()
#       7
#       8 #visualizeWaveforms()
# ----> 9 visualizeWaveforms(frequency, samplingRate, numHarmonics, waveType)
#      10
#      11 #IPython.display.Audio()
#
# /tmp/ipykernel_15802/2392447002.py in visualizeWaveforms(frequency, samplingRate, numHarmonics, waveType)
#      25
#      26   # call plotAudio2()
# ---> 27   plotAudio2(sig,sampleRate,title)
#      28
#      29   # call plotAudioFreqDomain()
#
# NameError: name 'sig' is not defined

# %%
frequency = 100
samplingRate = 44100
numHarmonics = 100
waveType = 'sawtooth'
winSize = 1024
specType = 'log'

#visualizeWaveforms()
#IPython.display.Audio()

# %%
frequency = 100
samplingRate = 44100
numHarmonics = 100
waveType = 'triangle'
winSize = 1024
specType = 'log'

#visualizeWaveforms()
#IPython.display.Audio()

# %%
frequency = 100
samplingRate = 44100
numHarmonics = 100
waveType = 'square'
winSize = 1024
specType = 'log'

#visualizeWaveforms()
#IPython.display.Audio()
